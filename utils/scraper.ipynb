# %%
import utils

# %%
target_sitemap = "https://sunic.co.kr"

extracted_urls = utils.get_urls_from_sitemap(target_sitemap,3)
# 최상단 dir, ppt파일 url 제거
extracted_urls = [url for url in extracted_urls[1:] if '.ppt' not in url.lower()]

scraped_dataset = utils.get_text_from_urls(extracted_urls)

utils.save_data_to_txt(scraped_dataset, "sunic_all_pages.txt")
# Out:
# 총 41개의 URL을 찾았습니다.
#
# 3개의 URL을 출력.
#
# 1: https://sunic.co.kr/
# 2: https://sunic.co.kr/web/home.php
# 3: https://sunic.co.kr/web/home.php?go=main
#
#
# [1/39] 크롤링 완료: https://sunic.co.kr/web/home.php
# [2/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=main
# [3/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Amenu_01
# [4/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Bmenu_01
# [5/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Fmenu_01
# [6/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Cmenu_01
# [7/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Dmenu_01
# [8/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Emenu_01
# [9/39] 크롤링 완료: https://sunic.co.kr/eng/home.php
# [10/39] 크롤링 완료: https://sunic.co.kr/chi/home.php
# [11/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Dmenu_01&item_num2=1023
# [12/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Dmenu_01&item_num2=1030
# [13/39] 크롤링 완료: https://sunic.co.kr/web/home.php?go=Dmenu_01&item_num2=1028
# ...
